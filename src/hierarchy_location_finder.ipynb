# %% [markdown]
# # Import libraries and initialized dotenv

# %%
from dotenv import load_dotenv
import os
import pandas as pd
import requests
import time
import psycopg2
load_dotenv()
# Out:
# True

# %% [markdown]
# # Define function to get coordinates for the dim_location table

# %%
# Function to get coordinates using OpenStreetMap Nominatim API
def get_coordinates(comune, provincia="Liguria", nazione="Italy"):
    """Get geographic coordinates for a location using Nominatim API"""
    if pd.notna(comune) and comune != "":
        search_query = f"{comune}, {provincia}, {nazione}"  # Format the search query
        url = f"https://nominatim.openstreetmap.org/search?q={search_query}&format=json&limit=1"
        
        try:
            # Add a delay to respect API rate limits
            time.sleep(1)
            response = requests.get(url, headers={"User-Agent": "CommuneCoordinatesFinder/1.0"})
            data = response.json()
            
            if data and len(data) > 0:
                return float(data[0]['lat']), float(data[0]['lon'])
        except Exception as e:
            print(f"Error fetching coordinates for {comune}: {e}")
    
    return None, None

# %% [markdown]
# # Define funcions to connect to the db, pass to a pandas df the needed data and save in the db the elabored df

# %%
def get_db_connection():
    """Create and return a database connection"""
    return psycopg2.connect(
        dbname=os.getenv('database'),
        user=os.getenv('User'),
        password=os.getenv('password'),
        host=os.getenv('host'),
        port=os.getenv('port')
    )

def get_connection_string():
    """Create a connection string."""
    return f"postgresql://{os.getenv('user')}:{os.getenv('password')}@{os.getenv('host')}:{os.getenv('port')}/{os.getenv('database')}"

def fetch_data_from_db(sql_file):
    """Fetch data from database using SQL file"""
    conn = get_db_connection()
    
    with open(sql_file, 'r') as file:   # Read the SQL file
        sql_query = file.read()
    
    cursor = conn.cursor()
    cursor.execute(sql_query)
    rows = cursor.fetchall()    # Fetch all rows from the executed query
    colnames = [desc[0] for desc in cursor.description] # Get column names from the cursor
    
    # Close the cursor and connection
    cursor.close()
    conn.close()
    
    return pd.DataFrame(rows, columns=colnames) # Create a Pandas DataFrame from the fetched data

def save_to_db(df, table_name):
    """Save dataframe to database"""
    conn = get_db_connection()
    
    try:
        df.to_sql(table_name, get_connection_string(), if_exists='replace', index=False)
        print(f"Data successfully saved to {table_name} table")
    except Exception as e:
        print(f"Error saving to database: {e}")
    finally:
        conn.close()

# %% [markdown]
# # Define fuctions to retructure the dataframe (DF) and correctly assign the locations hierarcy

# %%
def assign_data(df, filter_condition, id_column, columns_to_assign):
    """Helper function to assign data to dataframe rows matching a condition"""
    for col_name, value in columns_to_assign.items():
        df.loc[filter_condition, col_name] = value
    return df

def process_geographic_hierarchy(df, searchId):
    """
    searchid = # Starting search string (macroregion id ex: ITC For north West Italy)
    Process regions, provinces, and communes in the dataframe
    Regions: ITC + 1 character (e.g., ITC3)
    Provinces: Region code + 1 character (e.g., ITC3)
    Communes: Numbers found by searching province's name, first three numbers indicate province
    """
    # Add columns to the dataframe
    hierarchy_columns = ['Codice Regione', 'Codice Provincia', 'Codice Comune', 
                         'Regione', 'Provincia', 'Comune', 'Latitudine', 'Longitudine']
    for col in hierarchy_columns:
        df[col] = None
    
    # Step 1: Process regions
    comuneCodeLen = 3
    region_rows = df.loc[(df['id'].str.len() == len(searchId) + 1) & (df['id'].str.startswith(searchId))]
    
    # Process each region found
    for _, region_row in region_rows.iterrows():
        region_id = region_row['id']
        region_name = region_row['nome']
        
        # Assign region data
        assign_data(df, df['id'] == region_id, 'id', {
            'Regione': region_name,
            'Codice Regione': region_id
        })
        
        # Step 2: Process provinces for this region
        province_rows = df.loc[(df['id'].str.len() == len(region_id) + 1) & 
                               (df['id'].str.startswith(region_id))]
        
        # Process each province found
        for _, province_row in province_rows.iterrows():
            province_id = province_row['id']
            province_name = province_row['nome']
            
            # Assign province data
            assign_data(df, df['id'] == province_id, 'id', {
                'Provincia': province_name,
                'Codice Provincia': province_id,
                'Codice Regione': region_id
            })
            
            # Step 3: Find communes for this province by searching for province name
            main_com_rows = df.loc[df['nome'] == province_name]
            
            for _, main_com_row in main_com_rows.iterrows():
                commune_id = main_com_row['id']
                
                # Skip if this is the province ID itself
                if commune_id == province_id:
                    continue
                    
                # Extract the first three digits to use as the commune prefix
                if commune_id.isdigit() and len(commune_id) >= comuneCodeLen*2:
                    province_search_id = commune_id[:comuneCodeLen]
                    
                    # Find all communes of this province
                    commune_rows = df.loc[df['id'].str.startswith(province_search_id) & 
                                          (df['id'].str.isdigit())]
                    
                    # Process each commune found
                    for _, commune_row in commune_rows.iterrows():
                        commune_id = commune_row['id']
                        commune_name = commune_row['nome']
                        
                        # Assign commune data
                        assign_data(df, df['id'] == commune_id, 'id', {
                            'Comune': commune_name,
                            'Codice Comune': commune_id,
                            'Codice Provincia': province_id,
                            'Codice Regione': region_id,
                            'Provincia': province_name,
                            'Regione': region_name
                        })
    
    return df

# %% [markdown]
# # Define functions to add coordinates to the dataframe

# %%
def add_coordinates(df):
    """Add geographic coordinates to communes in the dataframe"""
    for index, row in df.iterrows():
        if pd.notna(row['Comune']) and row['Comune'] != "":
            # Get province name if available
            provincia = "Liguria"
            if pd.notna(row['Provincia']) and row['Provincia'] != "":
                provincia = row['Provincia']
            
            # Get coordinates
            print(f"Getting coordinates for {row['Comune']}")
            lat, lon = get_coordinates(row['Comune'], provincia)
            
            # Update the dataframe
            df.at[index, 'Latitudine'] = lat
            df.at[index, 'Longitudine'] = lon

    return df

def fill_missing_coordinates(df):
    """Fill missing coordinates for regions and provinces"""
    missing_coord_rows = df.loc[df['Latitudine'].isnull()]
    
    for idx, row in missing_coord_rows.iterrows():
        if pd.notna(row['Provincia']):
            # Try to find coordinates from the commune with the same name as the province
            matching_commune = df.loc[df['Comune'] == row['Provincia']]
            
            if not matching_commune.empty:
                lat = matching_commune.iloc[0]['Latitudine']
                lon = matching_commune.iloc[0]['Longitudine']
                
                if pd.notna(lat) and pd.notna(lon):
                    df.at[idx, 'Latitudine'] = lat
                    df.at[idx, 'Longitudine'] = lon
    
    return df

# %% [markdown]
# # Define Main

# %%
def main():
    searchId = 'ITC' # Starting search string
    # Get data from database
    df = fetch_data_from_db('select_location_hierarchy.sql')
    
    # Process geographic hierarchy
    df = process_geographic_hierarchy(df,searchId)
    
    # Print summary
    print(f"Processed {df['Codice Regione'].notna().sum()} regions")
    print(f"Processed {df['Codice Provincia'].notna().sum()} provinces")
    print(f"Processed {df['Codice Comune'].notna().sum()} communes")
    
    # Clean up dataframe
    df = df.drop(columns=['nome'])
    df = df.rename(columns={'id': 'Codice ISTAT'})
    
    # Add coordinates
    df = add_coordinates(df)

    # Fill missing coordinates
    df = fill_missing_coordinates(df)
    
    # Save to CSV
    #df.to_csv('gerarchia luogo con coordinate.csv', index=False)
    #print("Coordinates added and saved to 'gerarchia luogo con coordinate.csv'")
        
    # Save to database
    save_to_db(df, "gerarchia_luogo")
# Out:
# Processed 234 regions
# Processed 233 provinces
# Processed 229 communes

# %% [markdown]
# # Execute Main

# %%
if __name__ == "__main__":
    main()
# Out:
# Getting coordinates for Pigna
# Getting coordinates for Balestrino
# Getting coordinates for Millesimo
# Getting coordinates for Murialdo
# Getting coordinates for Casella
# Getting coordinates for Loano
# Getting coordinates for Vernazza
# Getting coordinates for Perinaldo
# Getting coordinates for Bormida
# Getting coordinates for Pietra Ligure
# Getting coordinates for Santo Stefano al Mare
# Getting coordinates for Borghetto d'Arroscia
# Getting coordinates for Ameglia
# Getting coordinates for Soldano
# Getting coordinates for Ranzo
# Getting coordinates for Dego
# Getting coordinates for Pornassio
# Getting coordinates for Montegrosso Pian Latte
# Getting coordinates for Leivi
# Getting coordinates for Tribogna
# Getting coordinates for Isola del Cantone
# Getting coordinates for Campomorone
# Getting coordinates for Borgio Verezzi
# Getting coordinates for Aurigo
# Getting coordinates for Stella
# Getting coordinates for Pignone
# Getting coordinates for Sassello
# Getting coordinates for Castelvecchio di Rocca Barbena
# Getting coordinates for Castiglione Chiavarese
# Getting coordinates for Roccavignale
# Getting coordinates for Spotorno
# Getting coordinates for Cicagna
# Getting coordinates for Triora
# Getting coordinates for Stellanello
# Getting coordinates for Orco Feglino
# Getting coordinates for Avegno
# Getting coordinates for Riva Ligure
# Getting coordinates for Taggia
# Getting coordinates for Sesta Godano
# Getting coordinates for Campo Ligure
# Getting coordinates for Bargagli
# Getting coordinates for Toirano
# Getting coordinates for Arenzano
# Getting coordinates for Fascia
# Getting coordinates for Olivetta San Michele
# Getting coordinates for Borzonasca
# Getting coordinates for Santo Stefano d'Aveto
# Getting coordinates for Costarainera
# Getting coordinates for Erli
# Getting coordinates for Luni
# Getting coordinates for Ceriale
# Getting coordinates for Diano Arentino
# Getting coordinates for Savignone
# Getting coordinates for Lavagna
# Getting coordinates for Bolano
# Getting coordinates for Levanto
# Getting coordinates for Framura
# Getting coordinates for Montoggio
# Getting coordinates for Serra Riccò
# Getting coordinates for Mendatica
# Getting coordinates for Airole
# Getting coordinates for Vado Ligure
# Getting coordinates for Cosio d'Arroscia
# Getting coordinates for Rondanina
# Getting coordinates for Urbe
# Getting coordinates for Piana Crixia
# Getting coordinates for Carasco
# Getting coordinates for Camporosso
# Getting coordinates for Andora
# Getting coordinates for Diano San Pietro
# Getting coordinates for San Bartolomeo al Mare
# Getting coordinates for Riccò del Golfo di Spezia
# Getting coordinates for Nasino
# Getting coordinates for Altare
# Getting coordinates for Arnasco
# Getting coordinates for Sarzana
# Getting coordinates for Fontanigorda
# Getting coordinates for Borgomaro
# Getting coordinates for Rocchetta Nervina
# Getting coordinates for Armo
# Getting coordinates for Chiusanico
# Getting coordinates for Albisola Superiore
# Getting coordinates for Magliolo
# Getting coordinates for Calice al Cornoviglio
# Getting coordinates for Quiliano
# Getting coordinates for Giusvalla
# Getting coordinates for Follo
# Getting coordinates for Cengio
# Getting coordinates for Ceriana
# Getting coordinates for Pallare
# Getting coordinates for Diano Castello
# Getting coordinates for Prelà
# Getting coordinates for Castelbianco
# Getting coordinates for Propata
# Getting coordinates for Rezzoaglio
# Getting coordinates for Recco
# Getting coordinates for Varese Ligure
# Getting coordinates for Bogliasco
# Getting coordinates for Castel Vittorio
# Getting coordinates for Testico
# Getting coordinates for Davagna
# Getting coordinates for Coreglia Ligure
# Getting coordinates for Bergeggi
# Getting coordinates for Beverino
# Getting coordinates for Camogli
# Getting coordinates for Gorreto
# Getting coordinates for Maissana
# Getting coordinates for Moconesi
# Getting coordinates for Onzo
# Getting coordinates for San Colombano Certenoli
# Getting coordinates for Celle Ligure
# Getting coordinates for Zignago
# Getting coordinates for Cosseria
# Getting coordinates for Vezzano Ligure
# Getting coordinates for Tiglieto
# Getting coordinates for Lumarzo
# Getting coordinates for Badalucco
# Getting coordinates for Bordighera
# Getting coordinates for Civezza
# Getting coordinates for Sori
# Getting coordinates for Rossiglione
# Getting coordinates for Vasia
# Getting coordinates for Finale Ligure
# Getting coordinates for Neirone
# Getting coordinates for Pietrabruna
# Getting coordinates for Pompeiana
# Getting coordinates for Genova
# Getting coordinates for Alassio
# Getting coordinates for Moneglia
# Getting coordinates for Busalla
# Getting coordinates for Lerici
# Getting coordinates for Boissano
# Getting coordinates for Borghetto di Vara
# Getting coordinates for Laigueglia
# Getting coordinates for Mallare
# Getting coordinates for Montebruno
# Getting coordinates for Imperia
# Getting coordinates for Caravonica
# Getting coordinates for Santa Margherita Ligure
# Getting coordinates for Garlenda
# Getting coordinates for Molini di Triora
# Getting coordinates for Borghetto Santo Spirito
# Getting coordinates for Albissola Marina
# Getting coordinates for Zuccarello
# Getting coordinates for Vallebona
# Getting coordinates for Calice Ligure
# Getting coordinates for Seborga
# Getting coordinates for Cervo
# Getting coordinates for Torriglia
# Getting coordinates for Rovegno
# Getting coordinates for Aquila d'Arroscia
# Getting coordinates for Casanova Lerrone
# Getting coordinates for Mezzanego
# Getting coordinates for Chiavari
# Getting coordinates for Vallecrosia
# Getting coordinates for Tovo San Giacomo
# Getting coordinates for Cipressa
# Getting coordinates for Rialto
# Getting coordinates for Lucinasco
# Getting coordinates for Carpasio
# Getting coordinates for Cogoleto
# Getting coordinates for Brugnato
# Getting coordinates for Ceranesi
# Getting coordinates for Albenga
# Getting coordinates for Portovenere
# Getting coordinates for Ronco Scrivia
# Getting coordinates for Calizzano
# Getting coordinates for Arcola
# Getting coordinates for Carcare
# Getting coordinates for Sestri Levante
# Getting coordinates for Osiglia
# Getting coordinates for Monterosso al Mare
# Getting coordinates for Pontedassio
# Getting coordinates for Noli
# Getting coordinates for Ne
# Getting coordinates for Plodio
# Getting coordinates for Cairo Montenotte
# Getting coordinates for Portofino
# Getting coordinates for Chiusavecchia
# Getting coordinates for Bardineto
# Getting coordinates for Deiva Marina
# Getting coordinates for Rezzo
# Getting coordinates for Castelnuovo Magra
# Getting coordinates for Dolceacqua
# Getting coordinates for Giustenice
# Getting coordinates for Lorsica
# Getting coordinates for Carrodano
# Getting coordinates for Casarza Ligure
# Getting coordinates for Mioglia
# Getting coordinates for Masone
# Getting coordinates for Rocchetta di Vara
# Getting coordinates for Rapallo
# Getting coordinates for Bajardo
# Getting coordinates for Isolabona
# Getting coordinates for Castellaro
# Getting coordinates for Diano Marina
# Getting coordinates for Villanova d'Albenga
# Getting coordinates for Pieve di Teco
# Getting coordinates for Pieve Ligure
# Getting coordinates for Mignanego
# Getting coordinates for Carro
# Getting coordinates for Vendone
# Getting coordinates for Cogorno
# Getting coordinates for Savona
# Getting coordinates for Ortovero
# Getting coordinates for Ospedaletti
# Getting coordinates for Vezzi Portio
# Getting coordinates for Sanremo
# Getting coordinates for Bonassola
# Getting coordinates for Terzorio
# Getting coordinates for Mele
# Getting coordinates for Cesio
# Getting coordinates for Orero
# Getting coordinates for La Spezia
# Getting coordinates for Riomaggiore
# Getting coordinates for Montalto Ligure
# Getting coordinates for Ventimiglia
# Getting coordinates for San Biagio della Cima
# Getting coordinates for Uscio
# Getting coordinates for Massimino
# Getting coordinates for Cisano sul Neva
# Getting coordinates for Pontinvrea
# Getting coordinates for Crocefieschi
# Getting coordinates for Favale di Malvaro
# Getting coordinates for Apricale
# Getting coordinates for Valbrevenna
# Getting coordinates for Varazze
# Getting coordinates for Sant'Olcese
# Getting coordinates for Santo Stefano di Magra
# Coordinates added and saved to 'gerarchia luogo con coordinate.csv'
